# %% [markdown]
# <a href="https://colab.research.google.com/github/Uros-Males/Minimization_Problem_On_Identical_Machines_Analysis/blob/main/XAnalyzing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IN PROGRESS....
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import time

df = pd.read_csv('/content/sample_data/C-instances-runtime-analysis(1).csv')

df = df[df['train'] == 1]

shuffled = df.sample(frac=1).reset_index()

columns_dont_want = ['y', 'index', 'inst.name', 'CPLEXStatus','type','train']
select = [x for x in shuffled.columns if x not in columns_dont_want]

X = shuffled.loc[:, select]

y = shuffled.loc[:,'y']

X['m/n'] = X['m/n'].apply(lambda x: x*100000)
X['(m/n)^2'] = X['(m/n)^2'].apply(lambda x: x*100000)
X['(m/n)^3'] = X['(m/n)^3'].apply(lambda x: x*100000)
shuffled = shuffled.drop(['train',  'index'], axis = 1)

# %%
X_corr = shuffled.corr()['y'].abs().sort_values(ascending=False)
X_corr
# Out:
# y            1.000000
# subtype      0.420955
# m/n          0.409521
# (m/n)^2      0.403926
# (m/n)^3      0.375878
# m            0.367326
# n/m          0.330493
# (n/m)^2      0.279131
# (n/m)^3      0.241554
# min          0.130981
# class        0.108656
# av.length    0.089859
# median       0.089041
# n            0.083849
# max          0.077182
# range        0.057945
# std.dev      0.026669
# k            0.023254
# indeks       0.011542
# Name: y, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif_scores(df):
    VIF_Scores = pd.DataFrame()
    VIF_Scores["Independent Features"] = df.columns
    VIF_Scores["VIF Scores"] = [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
    return VIF_Scores

vif_scores(X).round(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#    Independent Features  VIF Scores
# 0               subtype     11878.8
# 1                 class        10.4
# 2                indeks         4.7
# 3                     n        45.1
# 4                     m        21.3
# 5                   n/m    283263.1
# 6               (n/m)^2    430575.9
# 7               (n/m)^3     84162.1
# 8                   m/n     56964.8
# 9               (m/n)^2     70405.0
# 10              (m/n)^3     11641.4
# 11            av.length      2569.0
# 12              std.dev        54.5
# 13               median      1996.7
# 14                range         inf
# 15                  min         inf
# 16                  max         inf
# 17                    k        71.3

# %%
corr = X.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_ecb62_row0_col0, #T_ecb62_row1_col1, #T_ecb62_row2_col2, #T_ecb62_row3_col3, #T_ecb62_row4_col4, #T_ecb62_row5_col5, #T_ecb62_row6_col6, #T_ecb62_row7_col7, #T_ecb62_row8_col8, #T_ecb62_row9_col9, #T_ecb62_row10_col10, #T_ecb62_row11_col11, #T_ecb62_row11_col13, #T_ecb62_row12_col12, #T_ecb62_row13_col11, #T_ecb62_row13_col13, #T_ecb62_row14_col14, #T_ecb62_row15_col15, #T_ecb62_row16_col16, #T_ecb62_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ecb62_row0_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T
{
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_ecb62_row1_col17, #T_ecb62_row17_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_ecb62_row2_col0, #T_ecb62_row2_col8, #T_ecb62_row3_col5 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_ecb62_row2_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_ecb62_row2_col3, #T_ecb62_row5_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_ecb62_row2_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_ecb62_row2_col6, #T_ecb62_row12_col9 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_ecb62_row2_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_ecb62_row2_col9 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_ecb62_row2_col10, #T_ecb62_row4_col17 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_ecb62_row2_col13, #T_ecb62_row2_col14, #T_ecb62_row2_col15, #T_ecb62_row2_col17, #T_ecb62_row6_col4, #T_ecb62_row9_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_ecb62_row3_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_ecb62_row3_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_ecb62_row3_col4, #T_ecb62_row4_col10 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_ecb62_row3_col7, #T_ecb62_row11_col8, #T_ecb62_row12_col8, #T_ecb62_row13_col8, #T_ecb62_row15_col7, #T_ecb62_row16_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_ecb62_row3_col8, #T_ecb62_row14_col6, #T_ecb62_row15_col6 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_ecb62_row3_col10, #T_ecb62_row11_col7, #T_ecb62_row12_col4, #T_ecb62_row12_col7, #T_ecb62_row13_col7, #T_ecb62_row14_col7, #T_ecb62_row14_col8, #T_ecb62_row15_col8, #T_ecb62_row16_col4, #T_ecb62_row16_col7, #T_ecb62_row17_col8 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_ecb62_row3_col11, #T_ecb62_row14_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_ecb62_row3_col13 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_ecb62_row3_col14 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ecb62_row3_col15 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_ecb62_row3_col16 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_ecb62_row3_col17, #T_ecb62_row10_col4, #T_ecb62_row17_col11 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_ecb62_row4_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_ecb62_row4_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_ecb62_row4_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_ecb62_row4_col7 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_ecb62_row4_col8, #T_ecb62_row12_col17, #T_ecb62_row14_col15, #T_ecb62_row15_col14, #T_ecb62_row17_col12 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_ecb62_row4_col9 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_ecb62_row4_col11 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_ecb62_row4_col12, #T_ecb62_row4_col16 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_ecb62_row4_col13 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_ecb62_row4_col14 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_ecb62_row4_col15, #T_ecb62_row5_col14, #T_ecb62_row5_col17, #T_ecb62_row6_col9, #T_ecb62_row7_col12 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ecb62_row5_col0, #T_ecb62_row11_col12, #T_ecb62_row12_col11 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_ecb62_row5_col1, #T_ecb62_row7_col4, #T_ecb62_row10_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_ecb62_row5_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_ecb62_row5_col6, #T_ecb62_row6_col5, #T_ecb62_row8_col9, #T_ecb62_row9_col8, #T_ecb62_row13_col16, #T_ecb62_row14_col16, #T_ecb62_row16_col13, #T_ecb62_row16_col14 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_ecb62_row5_col7 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_ecb62_row5_col8, #T_ecb62_row9_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_ecb62_row5_col9, #T_ecb62_row6_col3, #T_ecb62_row7_col3 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ecb62_row5_col10 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_ecb62_row5_col15, #T_ecb62_row7_col11, #T_ecb62_row7_col13, #T_ecb62_row7_col14, #T_ecb62_row7_col16, #T_ecb62_row7_col17, #T_ecb62_row10_col7 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_ecb62_row6_col0, #T_ecb62_row11_col15, #T_ecb62_row13_col15, #T_ecb62_row15_col11, #T_ecb62_row15_col13 {
#   background-co

# %%
X_modified = X.drop(['max','subtype','indeks',  '(n/m)^2', '(n/m)^3', 'm/n', '(m/n)^2', '(m/n)^3', 'class', 'm', 'av.length', 'median', 'range', 'min'], axis = 1)
vif_scores(X_modified).round(1)
# Out:
#   Independent Features  VIF Scores
# 0                    n        22.3
# 1                  n/m         2.6
# 2              std.dev        13.7
# 3                    k        55.2

# %%
corr = X_modified.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0c1e1_row0_col0, #T_0c1e1_row1_col1, #T_0c1e1_row2_col2, #T_0c1e1_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0c1e1_row0_col1, #T_0c1e1_row1_col0, #T_0c1e1_row1_col2, #T_0c1e1_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0c1e1_row0_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_0c1e1_row0_col3 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_0c1e1_row2_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_0c1e1_row2_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_0c1e1_row2_col3, #T_0c1e1_row3_col2 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_0c1e1_row3_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_0c1e1_row3_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# </style>
# <table id="T_0c1e1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >n</th>
#       <th class="col_heading level0 col1" >n/m</th>
#       <th class="col_heading level0 col2" >std.dev</th>
#       <th class="col_heading level0 col3" >k</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c1e1_level0_row0" class="row_heading level0 row0" >n</th>
#       <td id="T_0c1e1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0c1e1_row0_col1" class="data row0 col1" >0.042415</td>
#       <td id="T_0c1e1_row0_col2" class="data row0 col2" >0.292127</td>
#       <td id="T_0c1e1_row0_col3" class="data row0 col3" >0.736769</td>
#     </tr>
#     <tr>
#       <th id="T_0c1e1_level0_row1" class="row_heading level0 row1" >n/m</th>
#       <td id="T_0c1e1_row1_col0" class="data row1 col0" >0.042415</td>
#       <td id="T_0c1e1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0c1e1_row1_col2" class="data row1 col2" >0.071609</td>
#       <td id="T_0c1e1_row1_col3" class="data row1 col3" >0.067416</td>
#     </tr>
#     <tr>
#       <th id="T_0c1e1_level0_row2" class="row_heading level0 row2" >std.dev</th>
#       <td id="T_0c1e1_row2_col0" class="data row2 col0" >0.292127</td>
#       <td id="T_0c1e1_row2_col1" class="data row2 col1" >0.071609</td>
#       <td id="T_0c1e1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0c1e1_row2_col3" class="data row2 col3" >0.805022</td>
#     </tr>
#     <tr>
#       <th id="T_0c1e1_level0_row3" class="row_heading level0 row3" >k</th>
#       <td id="T_0c1e1_row3_col0" class="data row3 col0" >0.736769</td>
#       <td id="T_0c1e1_row3_col1" class="data row3 col1" >0.067416</td>
#       <td id="T_0c1e1_row3_col2" class="data row3 col2" >0.805022</td>
#       <td id="T_0c1e1_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
